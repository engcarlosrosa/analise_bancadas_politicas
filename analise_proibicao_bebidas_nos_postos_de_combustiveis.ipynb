# %%
import sys, time
import pandas as pd
import datetime as dt
import networkx as nx
import matplotlib.pyplot as plt

from IPython.display import display

import plotly.plotly as py # interactive graphing
from plotly.graph_objs import Bar, Scatter, Marker, Layout

# %%
pd.options.display.max_rows = 100

# %%
df_pl_215= pd.read_excel('pl_215.xlsx')

# %%
list(df_pl_215.columns.values)
# Out:
# ['id_parlamentar', 'Parlamentar', 'Sigla', 'Partido Partido', 'Voto']

# %%
df_pl_215
# Out:
#     id_parlamentar               Parlamentar  Sigla Partido Partido  \
# 0                0       ABELARDO CAMARINHA      40            PSB
# 1                1            ADILSON ROSSI      40            PSB
# 2                2             AFONSO LOBATO     43              PV
# 3                3            ALDO DEMARCHI      25            DEM
# 4                4      ALENCAR LULA SANTANA     13              PT
# 5                5         ANA LULA DO CARMO     13              PT
# 6                6         ANALICE FERNANDES     45            PSDB
# 7                7           ANDRE DO PRADO      22              PR
# 8                8             ANDRE SOARES      27              DC
# 9                9    ANTONIO SALIM CURIATI      11              PP
# 10              10             BARROS MUNHOZ     40            PSB
# 11              11           BETH LULA SAHAO     13              PT
# 12              12              CAIO FRANCA      40            PSB
# 13              13            CAMPOS MACHADO     14             PTB
# 14              14          CARLAO PIGNATARI     45            PSDB
# 15              15        CARLOS BEZERRA JR.     45            PSDB
# 16              16             CARLOS CEZAR      40            PSB
# 17              17           CARLOS GIANNAZI     50            PSOL
# 18              18         CARLOS NEDER LULA     13              PT
# 19              19  CASSIO DE CASTRO NAVARRO     45            PSDB
# 20              20               CAUE MACRIS     45            PSDB
# 21              21                CELIA LEAO     45            PSDB
# 22              22            CELINO CARDOSO     45            PSDB
# 23              23      CELSO B. NASCIMENTO      20            PSC
# 24              24      CEZINHA DE MADUREIRA     55            PSD
# 25              25            CHICO SARDELLI     43              PV
# 26              26              CLELIA GOMES     70         AVANTE
# 27              27            CORONEL CAMILO     55             PSD
# 28              28           CORONEL TELHADA     11              PP
# 29              29                 DAVI ZAIA     23            PPS
# 30              30             DELEGADO OLIM     11              PP
# 31              31            DOUTOR ULYSSES     43              PV
# 32              32                 ED THOMAS     40            PSB
# 33              33             EDMIR CHEDID      25            DEM
# 34              34            EDSON GIRIBONI     43              PV
# 35              35           ENIO LULA TATTO     13              PT
# 36              36           ESTEVAM GALVAO      25            DEM
# 37              37          FELICIANO FILHO      44            PRP
# 38              38            FERNANDO CAPEZ     45            PSDB
# 39              39             FERNANDO CURY     23            PPS
# 40              40         GERALDO CRUZ LULA     13              PT
# 41              41            GIL LANCASTER      40            PSB
# 42              42              GILENO GOMES     90           PROS
# 43              43           GILMACI SANTOS      10            PRB
# 44              44            GILMAR GIMENES     45            PSDB
# 45              45             GUSTAVO PETTA     65        PC DO B
# 46              46           HELIO NISHIMOTO     45            PSDB
# 47              47             ITAMAR BORGES     15            MDB
# 48              48             JOAO CARAMEZ      40            PSB
# 49              49          JOAO PAULO RILLO     50            PSOL
# 50              50                JOOJI HATO     15            MDB
# 51              51             JORGE CARUSO      15            MDB
# 52              52             JORGE WILSON      10            PRB
# 53              53         JOSE AMERICO LULA     13              PT
# 54              54      JOSE ZICO LULA PRADO     13              PT
# 55              55              LECI BRANDAO     65        PC DO B
# 56              56              LEO OLIVEIRA     15            MDB
# 57              57        LUIZ CARLOS GONDIM     14             PTB
# 58              58        LUIZ FERNANDO LULA     13              PT
# 59              59           LUIZ TURCO LULA     13              PT
# 60              60           MARCIA LULA LIA     13              PT
# 61              61            MARCIO CAMARGO     45            PSDB
# 62              62             MARCO VINHOLI     45            PSDB
# 63              63           MARCOS DAMASIO      22              PR
# 64              64       MARCOS LULA MARTINS     13              PT
# 65              65            MARCOS ZERBINI     45            PSDB
# 66              66         MARIA LUCIA AMARY     45            PSDB
# 67              67               MARTA COSTA     55             PSD
# 68              68       MILTON LEITE FILHO      25            DEM
# 69              69            MILTON VIEIRA      10            PRB
# 70              70          ORLANDO BOLCONE      40            PSB
# 71              71          PAULO CORREA JR.     51          PATRI
# 72              72                PEDRO KAKA     19            PODE
# 73              73              PEDRO TOBIAS     45            PSDB
# 74              74          PROF AURIEL LULA     13              PT
# 75              75             RAFAEL SILVA      40            PSB
# 76              76      RAMALHO DACONSTRUCAO     45            PSDB
# 77              77              RAUL MARCELO     50            PSOL
# 78              78            REINALDO ALGUZ     43              PV
# 79              79          RICARDO MADALENA     22              PR
# 80              80               RITA PASSOS     55             PSD
# 81              81            ROBERTO ENGLER     40            PSB
# 82              82         ROBERTO MASSAFERA     45            PSDB
# 83              83            ROBERTO MORAIS     23            PPS
# 84              84           ROBERTO TRIPOLI     43              PV
# 85              85            RODRIGO MORAES     25            DEM
# 86              86          ROGERIO NOGUEIRA     25            DEM
# 87              87            ROQUE BARBIERE     14             PTB
# 88              88         SEBASTIAO SANTOS      10            PRB
# 89              89       TEONILIO BARBA LULA     13              PT
# 90              90               VAZ DE LIMA     45            PSDB
# 91              91            VITOR SAPIENZA     23            PPS
# 92              92          WELLINGTON MOURA     10            PRB
# 93              93          WELSON GASPARINI     45            PSDB
#
#           Voto
# 0    Obstrucao
# 1    Obstrucao
# 2          Sim
# 3    Obstrucao
# 4    Obstrucao
# 5    Obstrucao
# 6    Obstrucao
# 7          ---
# 8          ---
# 9          ---
# 10         Sim
# 11         Sim
# 12         Nao
# 13         ---
# 14   Obstrucao
# 15   Obstrucao
# 16         Sim
# 17         Nao
# 18   Obstrucao
# 19   Obstrucao
# 20  Licenciado
# 21         Sim
# 22   Obstrucao
# 23         Sim
# 24   Obstrucao
# 25   Obstrucao
# 26         ---
# 27         Sim
# 28         ---
# 29         Sim
# 30         ---
# 31         Sim
# 32   Obstrucao
# 33   Obstrucao
# 34         Sim
# 35         Sim
# 36         Sim
# 37         ---
# 38   Obstrucao
# 39         ---
# 40   Obstrucao
# 41         Sim
# 42         Sim
# 43         Sim
# 44   Obstrucao
# 45   Obstrucao
# 46   Obstrucao
# 47         Sim
# 48         Sim
# 49         Nao
# 50  Licenciado
# 51         Sim
# 52         Sim
# 53         Nao
# 54   Obstrucao
# 55         Sim
# 56   Obstrucao
# 57         ---
# 58         Sim
# 59   Obstrucao
# 60         Sim
# 61   Obstrucao
# 62         Nao
# 63         Sim
# 64   Obstrucao
# 65   Obstrucao
# 66         ---
# 67   Obstrucao
# 68   Obstrucao
# 69   Obstrucao
# 70         Sim
# 71         ---
# 72         ---
# 73   Obstrucao
# 74   Obstrucao
# 75   Obstrucao
# 76   Obstrucao
# 77         Sim
# 78         Sim
# 79         ---
# 80   Obstrucao
# 81   Obstrucao
# 82   Obstrucao
# 83         ---
# 84   Obstrucao
# 85         Sim
# 86         Sim
# 87         ---
# 88   Obstrucao
# 89   Abstencao
# 90   Obstrucao
# 91         ---
# 92         Sim
# 93   Obstrucao

# %%
df = df_pl_215

# %% [markdown]
# # Data preparation

# %% [markdown]
# ### Votação PL 215

# %%
column_edge = 'Voto'
column_ID = 'id_parlamentar'

data_to_merge = df[[column_ID, column_edge]].dropna(subset=[column_edge]).drop_duplicates() # select columns, remove NaN

# To create connections between people who have the same number,
# join data with itself on the 'ID' column.
data_to_merge = data_to_merge.merge(
    data_to_merge[[column_ID, column_edge]].rename(columns={column_ID:column_ID+"_2"}), 
    on=column_edge
)

# %%
# By joining the data with itself, people will have a connection with themselves.
# Remove self connections, to keep only connected people who are different.
d = data_to_merge[~(data_to_merge[column_ID]==data_to_merge[column_ID+"_2"])] \
    .dropna()[[column_ID, column_ID+"_2", column_edge]]
    
# To avoid counting twice the connections (person 1 connected to person 2 and person 2 connected to person 1)
# we force the first ID to be "lower" then ID_2
d.drop(d.loc[d[column_ID+"_2"]<d[column_ID]].index.tolist(), inplace=True)

# %%
G = nx.from_pandas_edgelist(df=d, source=column_ID, target=column_ID+'_2', edge_attr=column_edge)

G.add_nodes_from(nodes_for_adding=df.id_parlamentar.tolist())

# %%
G.nodes()
# Out:
# NodeView((0, 1, 3, 4, 5, 6, 14, 15, 18, 19, 22, 24, 25, 32, 33, 38, 40, 44, 45, 46, 54, 56, 59, 61, 64, 65, 67, 68, 69, 73, 74, 75, 76, 80, 81, 82, 84, 88, 90, 93, 2, 10, 11, 16, 21, 23, 27, 29, 31, 34, 35, 36, 41, 42, 43, 47, 48, 51, 52, 55, 58, 60, 63, 70, 77, 78, 85, 86, 92, 7, 8, 9, 13, 26, 28, 30, 37, 39, 57, 66, 71, 72, 79, 83, 87, 91, 12, 17, 49, 53, 62, 20, 50, 89))

# %% [markdown]
# ### Partidos

# %%
column_edge = 'Partido Partido'
column_ID = 'id_parlamentar'

data_to_merge = df[[column_ID, column_edge]].dropna(subset=[column_edge]).drop_duplicates()

data_to_merge = data_to_merge.merge(
    data_to_merge[[column_ID, column_edge]].rename(columns={column_ID:column_ID+"_2"}), 
    on=column_edge
)

d = data_to_merge[~(data_to_merge[column_ID]==data_to_merge[column_ID+"_2"])] \
    .dropna()[[column_ID, column_ID+"_2", column_edge]]

d.drop(d.loc[d[column_ID+"_2"]<d[column_ID]].index.tolist(), inplace=True)

# %%
# Create the connections in the graph
links_attributes = {tuple(row[[column_ID, column_ID+"_2"]]): {column_edge: row[column_edge]} for i,row in d.iterrows()}

G.add_edges_from(links_attributes) # create the connection, without attribute. Check it with G.get_edge_data(3,5)
nx.set_edge_attributes(G=G, values=links_attributes) # adds the attribute. Check it with G.get_edge_data(3,5)

# %% [markdown]
# # Graph analysis

# %% [markdown]
# ### Drawing graphs

# %%
nx.draw(G, node_size=10, edge_color='b', edge_width=1, with_labels=True, node_label_position ='top center')

# %%
nx.write_gml(G, 'pl_215.gml')
# Out:
# ---------------------------------------------------------------------------
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-15-64349a1b28fc> in <module>()
# ----> 1 nx.write_gml(G, 'pl_215.gml')
#
# <decorator-gen-561> in write_gml(G, path, stringizer)
#
# ~\Anaconda3\lib\site-packages\networkx\utils\decorators.py in _open_file(func_to_be_decorated, *args, **kwargs)
#     225         # Finally, we call the original function, making sure to close the fobj
#     226         try:
# --> 227             result = func_to_be_decorated(*new_args, **kwargs)
#     228         finally:
#     229             if close_fobj:
#
# ~\Anaconda3\lib\site-packages\networkx\readwrite\gml.py in write_gml(G, path, stringizer)
#     808     >>> nx.write_gml(G, "test.gml.gz")
#     809     """
# --> 810     for line in generate_gml(G, stringizer):
#     811         path.write((line + '\n').encode('ascii'))
#     812
#
# ~\Anaconda3\lib\site-packages\networkx\readwrite\gml.py in generate_gml(G, stringizer)
#     745                 yield line
#     746         for attr, value in e[-1].items():
# --> 747             for line in stringize(attr, value, ignored_keys, '    '):
#     748                 yield line
#     749         yield '  ]'
#
# ~\Anaconda3\lib\site-packages\networkx\readwrite\gml.py in stringize(key, value, ignored_keys, indent, in_list)
#     655             raise NetworkXError('%r is not a string' % (key,))
#     656         if not valid_keys.match(key):
# --> 657             raise NetworkXError('%r is not a valid key' % (key,))
#     658         if not isinstance(key, str):
#     659             key = str(key)
#
# NetworkXError: 'Partido Partido' is not a valid key
