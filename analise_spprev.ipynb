# %%
import sys, time
import pandas as pd
import datetime as dt
import networkx as nx
import matplotlib.pyplot as plt

from IPython.display import display

import plotly.plotly as py # interactive graphing
from plotly.graph_objs import Bar, Scatter, Marker, Layout

# %%
pd.options.display.max_rows = 100

# %%
df_spprev_em_investimento_imobiliário= pd.read_excel('spprev_em_investimento_imobiliário.xlsx')

# %%
df_spprev_em_investimento_imobiliário
# Out:
#     id_parlamentar               Parlamentar  Sigla  Partido        Voto
# 0                0        ABELARDO CAMARINHA     40      PSB         Sim
# 1                1             ADILSON ROSSI     40      PSB         Sim
# 2                2             AFONSO LOBATO     43       PV         Sim
# 3                3             ALDO DEMARCHI     25      DEM         Sim
# 4                4              ANA DO CARMO     13       PT   Obstrucao
# 5                5         ANALICE FERNANDES     45     PSDB         Sim
# 6                6            ANDRE DO PRADO     22       PR         Sim
# 7                7              ANDRE SOARES     25      DEM   Obstrucao
# 8                8     ANTONIO SALIM CURIATI     11       PP         Sim
# 9                9                BETH SAHAO     13       PT         Nao
# 10              10          CARLAO PIGNATARI     45     PSDB         Sim
# 11              11        CARLOS BEZERRA JR.     45     PSDB         Sim
# 12              12           CARLOS GIANNAZI     50     PSOL         Nao
# 13              13              CARLOS NEDER     13       PT   Obstrucao
# 14              14  CASSIO DE CASTRO NAVARRO     15     PMDB         Sim
# 15              15                CELIA LEAO     45     PSDB         Sim
# 16              16            CELINO CARDOSO     45     PSDB         Sim
# 17              17       CELSO B. NASCIMENTO     20      PSC         Sim
# 18              18              CELSO GIGLIO     45     PSDB  Licenciado
# 19              19      CEZINHA DE MADUREIRA     25      DEM   Obstrucao
# 20              20            CHICO SARDELLI     43       PV   Obstrucao
# 21              21           CORONEL TELHADA     45     PSDB         Sim
# 22              22                 DAVI ZAIA     23      PPS         Sim
# 23              23            DOUTOR ULYSSES     43       PV         Sim
# 24              24                 ED THOMAS     40      PSB         Sim
# 25              25              EDMIR CHEDID     25      DEM         Sim
# 26              26                ENIO TATTO     13       PT   Obstrucao
# 27              27            ESTEVAM GALVAO     25      DEM         Sim
# 28              28           FELICIANO FILHO     20      PSC         Sim
# 29              29            FERNANDO CAPEZ     45     PSDB         Sim
# 30              30             FERNANDO CURY     23      PPS         Sim
# 31              31           G BARROS MUNHOZ     45     PSDB         Sim
# 32              32              GERALDO CRUZ     13       PT   Obstrucao
# 33              33             GIL LANCASTER     25      DEM         Sim
# 34              34            GILMACI SANTOS     10      PRB         Sim
# 35              35            GILMAR GIMENES     11       PP         Sim
# 36              36           HELIO NISHIMOTO     45     PSDB         Sim
# 37              37              JOAO CARAMEZ     45     PSDB         Sim
# 38              38          JOAO PAULO RILLO     13       PT   Obstrucao
# 39              39                JOOJI HATO     15     PMDB  Licenciado
# 40              40              JORGE CARUSO     15     PMDB         Sim
# 41              41              JORGE WILSON     10      PRB         Sim
# 42              42              JOSE AMERICO     13       PT         Nao
# 43              43           JOSE ZICO PRADO     13       PT         Nao
# 44              44         JUNIOR APRILLANTI     40      PSB         Sim
# 45              45         L ALENCAR SANTANA     13       PT         Nao
# 46              46             L CAIO FRANCA     40      PSB         Sim
# 47              47          L CAMPOS MACHADO     14      PTB         Sim
# 48              48            L CLELIA GOMES     31      PHS         Sim
# 49              49          L CORONEL CAMILO     55      PSD         Sim
# 50              50           L DELEGADO OLIM     11       PP         Sim
# 51              51          L EDSON GIRIBONI     43       PV         Sim
# 52              52            L GILENO GOMES     17      PSL         Sim
# 53              53           L ITAMAR BORGES     15     PMDB         Sim
# 54              54            L LECI BRANDAO     65  PC DO B         NaN
# 55              55      L LUIZ CARLOS GONDIM     77       SD         NaN
# 56              56          L MARCIO CAMARGO     20      PSC         Sim
# 57              57        L PAULO CORREA JR.     51      PEN         Sim
# 58              58              L PEDRO KAKA     19     PODE         Sim
# 59              59            L RAFAEL SILVA     12      PDT         ---
# 60              60            L RAUL MARCELO     50     PSOL   Obstrucao
# 61              61        L RICARDO MADALENA     22       PR         Sim
# 62              62       L ROBERTO MASSAFERA     45     PSDB         Sim
# 63              63          L ROBERTO MORAIS     23      PPS         Sim
# 64              64        L ROGERIO NOGUEIRA     25      DEM         Sim
# 65              65        L WELLINGTON MOURA     10      PRB         Sim
# 66              66              LEO OLIVEIRA     15     PMDB         Sim
# 67              67             LUIZ FERNANDO     13       PT   Obstrucao
# 68              68                LUIZ TURCO     13       PT   Obstrucao
# 69              69              M MARCIA LIA     13       PT         Nao
# 70              70             MARCO VINHOLI     45     PSDB         Sim
# 71              71            MARCOS DAMASIO     22       PR         Sim
# 72              72            MARCOS MARTINS     13       PT   Obstrucao
# 73              73            MARCOS ZERBINI     45     PSDB         Sim
# 74              74         MARIA LUCIA AMARY     45     PSDB         Sim
# 75              75               MARTA COSTA     55      PSD         Sim
# 76              76        MILTON LEITE FILHO     25      DEM   Obstrucao
# 77              77             MILTON VIEIRA     10      PRB         Sim
# 78              78           ORLANDO BOLCONE     40      PSB         Sim
# 79              79             P CAUE MACRIS     45     PSDB         NaN
# 80              80              PEDRO TOBIAS     45     PSDB         Sim
# 81              81          PROFESSOR AURIEL     13       PT   Obstrucao
# 82              82      RAMALHO DACONSTRUCAO     45     PSDB         Sim
# 83              83            REINALDO ALGUZ     43       PV         Sim
# 84              84               RITA PASSOS     55      PSD         Sim
# 85              85            ROBERTO ENGLER     45     PSDB         Sim
# 86              86           ROBERTO TRIPOLI     43       PV   Obstrucao
# 87              87            RODRIGO MORAES     25      DEM         Sim
# 88              88            ROQUE BARBIERE     14      PTB         Sim
# 89              89            S CARLOS CEZAR     40      PSB         Sim
# 90              90          SEBASTIAO SANTOS     10      PRB         Sim
# 91              91            TEONILIO BARBA     13       PT         Nao
# 92              92               VAZ DE LIMA     45     PSDB         Sim
# 93              93          WELSON GASPARINI     45     PSDB         Sim

# %%
df = df_spprev_em_investimento_imobiliário

# %% [markdown]
# # Data preparation

# %% [markdown]
# ### Votação SPPREV

# %% [markdown]
# #### Ementa:	Autoriza a participação da São Paulo Previdência - SPPREV em Fundo de Investimento Imobiliário e dá outras providências.

# %% [markdown]
# #### Indexadores: AUTORIZAÇÃO, FUNDO DE INVESTIMENTO IMOBILIÁRIO, PARTICIPAÇÃO, SÃO PAULO PREVIDÊNCIA - SPPREV

# %%
column_edge = 'Voto'
column_ID = 'id_parlamentar'

data_to_merge = df[[column_ID, column_edge]].dropna(subset=[column_edge]).drop_duplicates() # select columns, remove NaN

# To create connections between people who have the same number,
# join data with itself on the 'ID' column.
data_to_merge = data_to_merge.merge(
    data_to_merge[[column_ID, column_edge]].rename(columns={column_ID:column_ID+"_2"}), 
    on=column_edge
)

# %%
# By joining the data with itself, people will have a connection with themselves.
# Remove self connections, to keep only connected people who are different.
d = data_to_merge[~(data_to_merge[column_ID]==data_to_merge[column_ID+"_2"])] \
    .dropna()[[column_ID, column_ID+"_2", column_edge]]
    
# To avoid counting twice the connections (person 1 connected to person 2 and person 2 connected to person 1)
# we force the first ID to be "lower" then ID_2
d.drop(d.loc[d[column_ID+"_2"]<d[column_ID]].index.tolist(), inplace=True)

# %%
G = nx.from_pandas_edgelist(df=d, source=column_ID, target=column_ID+'_2', edge_attr=column_edge)

G.add_nodes_from(nodes_for_adding=df.id_parlamentar.tolist())

# %%
G.nodes()
# Out:
# NodeView((0, 1, 2, 3, 5, 6, 8, 10, 11, 14, 15, 16, 17, 21, 22, 23, 24, 25, 27, 28, 29, 30, 31, 33, 34, 35, 36, 37, 40, 41, 44, 46, 47, 48, 49, 50, 51, 52, 53, 56, 57, 58, 61, 62, 63, 64, 65, 66, 70, 71, 73, 74, 75, 77, 78, 80, 82, 83, 84, 85, 87, 88, 89, 90, 92, 93, 4, 7, 13, 19, 20, 26, 32, 38, 60, 67, 68, 72, 76, 81, 86, 9, 12, 42, 43, 45, 69, 91, 18, 39, 54, 55, 59, 79))

# %% [markdown]
# ### Partidos

# %%
column_edge = 'Partido'
column_ID = 'id_parlamentar'

data_to_merge = df[[column_ID, column_edge]].dropna(subset=[column_edge]).drop_duplicates()

data_to_merge = data_to_merge.merge(
    data_to_merge[[column_ID, column_edge]].rename(columns={column_ID:column_ID+"_2"}), 
    on=column_edge
)

d = data_to_merge[~(data_to_merge[column_ID]==data_to_merge[column_ID+"_2"])] \
    .dropna()[[column_ID, column_ID+"_2", column_edge]]

d.drop(d.loc[d[column_ID+"_2"]<d[column_ID]].index.tolist(), inplace=True)

# %%
# Create the connections in the graph
links_attributes = {tuple(row[[column_ID, column_ID+"_2"]]): {column_edge: row[column_edge]} for i,row in d.iterrows()}

G.add_edges_from(links_attributes) # create the connection, without attribute. Check it with G.get_edge_data(3,5)
nx.set_edge_attributes(G=G, values=links_attributes) # adds the attribute. Check it with G.get_edge_data(3,5)

# %% [markdown]
# # Graph analysis

# %% [markdown]
# ### Drawing graphs

# %%
nx.draw(G, node_size=10, edge_color='b', edge_width=1, with_labels=True, node_label_position ='top center')
