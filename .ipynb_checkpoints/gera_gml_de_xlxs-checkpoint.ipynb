# %%
import sys, time
import pandas as pd
import datetime as dt
from IPython.display import display

import plotly.plotly as py # interactive graphing
from plotly.graph_objs import Bar, Scatter, Marker, Layout

# %%
df_pl_215= pd.read_excel('pl_215.xlsx')

# %%
list(df_pl_215.columns.values)
# Out:
# ['id_parlamentar', 'Parlamentar', 'Sigla', 'Partido', 'Voto']

# %%
df_pl_215
# Out:
#     id_parlamentar             Parlamentar  Sigla   Partido        Voto
# 0                1            CLELIA GOMES     70   AVANTE          ---
# 1                2           ANDRE SOARES      27        DC         ---
# 2                3          ALDO DEMARCHI      25      DEM    Obstrucao
# 3                4           EDMIR CHEDID      25      DEM    Obstrucao
# 4                5         ESTEVAM GALVAO      25      DEM          Sim
# 5                6     MILTON LEITE FILHO      25      DEM    Obstrucao
# 6                7          RODRIGO MORAES     25      DEM          Sim
# 7                8        ROGERIO NOGUEIRA     25      DEM          Sim
# 8                9           ITAMAR BORGES     15      MDB          Sim
# 9               10              JOOJI HATO     15      MDB   Licenciado
# 10              11           JORGE CARUSO      15      MDB          Sim
# 11              12            LEO OLIVEIRA     15      MDB    Obstrucao
# 12              13        PAULO CORREA JR.     51    PATRI          ---
# 13              14           GUSTAVO PETTA     65  PC DO B    Obstrucao
# 14              15            LECI BRANDAO     65  PC DO B          Sim
# 15              16              PEDRO KAKA     19      PODE         ---
# 16              17  ANTONIO SALIM CURIATI      11        PP         ---
# 17              18         CORONEL TELHADA     11        PP         ---
# 18              19           DELEGADO OLIM     11        PP         ---
# 19              20               DAVI ZAIA     23      PPS          Sim
# 20              21           FERNANDO CURY     23      PPS          ---
# 21              22          ROBERTO MORAIS     23      PPS          ---
# 22              23          VITOR SAPIENZA     23      PPS          ---
# 23              24         ANDRE DO PRADO      22        PR         ---
# 24              25         MARCOS DAMASIO      22        PR         Sim
# 25              26        RICARDO MADALENA     22        PR         ---
# 26              27         GILMACI SANTOS      10      PRB          Sim
# 27              28           JORGE WILSON      10      PRB          Sim
# 28              29          MILTON VIEIRA      10      PRB    Obstrucao
# 29              30       SEBASTIAO SANTOS      10      PRB    Obstrucao
# ..             ...                     ...    ...       ...         ...
# 64              65    RAMALHO DACONSTRUCAO     45      PSDB   Obstrucao
# 65              66       ROBERTO MASSAFERA     45      PSDB   Obstrucao
# 66              67             VAZ DE LIMA     45      PSDB   Obstrucao
# 67              68        WELSON GASPARINI     45      PSDB   Obstrucao
# 68              69         CARLOS GIANNAZI     50      PSOL         Nao
# 69              70        JOAO PAULO RILLO     50      PSOL         Nao
# 70              71            RAUL MARCELO     50      PSOL         Sim
# 71              72    ALENCAR LULA SANTANA     13        PT   Obstrucao
# 72              73       ANA LULA DO CARMO     13        PT   Obstrucao
# 73              74         BETH LULA SAHAO     13        PT         Sim
# 74              75       CARLOS NEDER LULA     13        PT   Obstrucao
# 75              76         ENIO LULA TATTO     13        PT         Sim
# 76              77       GERALDO CRUZ LULA     13        PT   Obstrucao
# 77              78       JOSE AMERICO LULA     13        PT         Nao
# 78              79    JOSE ZICO LULA PRADO     13        PT   Obstrucao
# 79              80      LUIZ FERNANDO LULA     13        PT         Sim
# 80              81         LUIZ TURCO LULA     13        PT   Obstrucao
# 81              82         MARCIA LULA LIA     13        PT         Sim
# 82              83     MARCOS LULA MARTINS     13        PT   Obstrucao
# 83              84        PROF AURIEL LULA     13        PT   Obstrucao
# 84              85     TEONILIO BARBA LULA     13        PT   Abstencao
# 85              86          CAMPOS MACHADO     14       PTB         ---
# 86              87      LUIZ CARLOS GONDIM     14       PTB         ---
# 87              88          ROQUE BARBIERE     14       PTB         ---
# 88              89           AFONSO LOBATO     43        PV         Sim
# 89              90          CHICO SARDELLI     43        PV   Obstrucao
# 90              91          DOUTOR ULYSSES     43        PV         Sim
# 91              92          EDSON GIRIBONI     43        PV         Sim
# 92              93        L REINALDO ALGUZ     43        PV         Sim
# 93              94         ROBERTO TRIPOLI     43        PV   Obstrucao
#
# [94 rows x 5 columns]

# %%
#Utility functions
def progress(v):
    v = str(v)
    sys.stdout.flush()
    sys.stdout.write('\r')
    sys.stdout.flush()
    sys.stdout.write(v)

# %%
FILE_NAME = "pl_215.gml"

# %%
f = open(FILE_NAME, "w")
#helpers
s = " "
ss = s+s
sss = s+s+s
ssss = s+s+s+s
nl = "\n"

#loop helpers
added = []
ind = 0

#Root node
f.write("graph"+nl)
f.write("["+nl)

#Write an edge
def write_edge(r):
    f.write( ss + "edge" + nl)
    f.write( ss + "[" + nl)
    f.write( ssss + "source" + s + '"' + str(r['id_parlamentar']) + '"' + nl)
    f.write( ssss + "target" + s + '"' + str(r['Sigla']) + '"' + nl)
    f.write( ssss + "value" + s + '"' + str(r['Voto']) + '"' + nl)
    f.write( ss + "]"+ nl)

#Write a node
def write_node(r):
    f.write( ss + "node" + nl)
    f.write( ss + "[" + nl)
    f.write( ssss + "id" + s + '"' + str(r['id_parlamentar']) + '"' + nl)
    f.write( ssss + "label" + s + '"' + str(r['Parlamentar']) + '"' + nl)
    f.write( ss + "]"+ nl)


#Generate nodes
for i, r in df_pl_215.iterrows():
    #increment, as index not reliable
    ind += 1
    #Check for duplicates
    if (r['id_parlamentar'] not in added):
        #Add to list
        added.append(r['id_parlamentar'])
        write_node(r)
    #print the progress    
    progress(ind)

print(nl+"Printing nodes over")

#flush index
ind = 0    
#Generate edges    
for i, r in df_pl_215.iterrows():
    #increment, as index not reliable
    ind += 1
    if(r['id_parlamentar'] < r['Sigla']):
        write_edge(r)
    #print the progress            
    progress(ind)

print(nl+"Printing nodes and edges over")

#closing node
f.write("]"+nl)
f.close()
# Out:
# 94
# Printing nodes over
# 94
# Printing nodes and edges over
